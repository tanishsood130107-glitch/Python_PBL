# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("PBL_DATA_SET_7.csv")

# %%
# df.to_excel("INITAL_DATA_SET_7.xlsx", index = False)

# %%
df.head()
# Out:
#    CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 0      17850.0        NaN     85123A         2  2010-12-01 08:26:00
# 1      17850.0     536365      71053         8                  NaN
# 2     -17850.0        NaN     84406B         4  2010-12-01 08:26:00
# 3      17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4      17850.0     536365     84029E         1  2010-12-01 08:26:00
#
#    UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 0     -165.75           Others             N                     0
# 1      220.35           Others            NO                     0
# 2      178.75      Kitchenware            No                     0
# 3      220.35           Others             N                     0
# 4      220.35           Others            No                     0

# %%
df.shape
# Out:
# (495478, 9)

# %%
df.columns
# Out:
# Index(['CUSTOMER_ID', 'INVOICE_NO', 'STOCK_CODE', 'QUANTITY', 'INVOICE_DATE',
#        'UNIT_PRICE', 'PRODUCT_CATEGORY', 'ITEM_RETURNED',
#        'NO_OF_ITEMS_RETURNED'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495478 entries, 0 to 495477
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CUSTOMER_ID           337792 non-null  float64
#  1   INVOICE_NO            448631 non-null  object
#  2   STOCK_CODE            470224 non-null  object
#  3   QUANTITY              495478 non-null  int64
#  4   INVOICE_DATE          448239 non-null  object
#  5   UNIT_PRICE            449081 non-null  float64
#  6   PRODUCT_CATEGORY      457934 non-null  object
#  7   ITEM_RETURNED         495478 non-null  object
#  8   NO_OF_ITEMS_RETURNED  495478 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 34.0+ MB

# %%
df.describe()
# Out:
#          CUSTOMER_ID       QUANTITY    UNIT_PRICE  NO_OF_ITEMS_RETURNED
# count  337792.000000  495478.000000  4.490810e+05         495478.000000
# mean    13426.081136       2.502024  2.345314e+02              0.334073
# std      8001.156870       2.184020  6.678495e+03              1.122730
# min    -18287.000000      -1.000000 -7.190339e+05              0.000000
# 25%     13988.000000       1.000000  5.395000e+01              0.000000
# 50%     15311.000000       2.000000  1.098500e+02              0.000000
# 75%     16859.000000       3.000000  2.437500e+02              0.000000
# max     18287.000000      11.000000  2.533050e+06             15.000000

# %%
df.isnull().sum()
# Out:
# CUSTOMER_ID             157686
# INVOICE_NO               46847
# STOCK_CODE               25254
# QUANTITY                     0
# INVOICE_DATE             47239
# UNIT_PRICE               46397
# PRODUCT_CATEGORY         37544
# ITEM_RETURNED                0
# NO_OF_ITEMS_RETURNED         0
# dtype: int64

# %%
(df["CUSTOMER_ID"].isnull().mean()) * 100
# Out:
# np.float64(31.825025530901474)

# %%
df = df.dropna(subset=["CUSTOMER_ID"])

# %%
df.head()
# Out:
#    CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 0      17850.0        NaN     85123A         2  2010-12-01 08:26:00
# 1      17850.0     536365      71053         8                  NaN
# 2     -17850.0        NaN     84406B         4  2010-12-01 08:26:00
# 3      17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4      17850.0     536365     84029E         1  2010-12-01 08:26:00
#
#    UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 0     -165.75           Others             N                     0
# 1      220.35           Others            NO                     0
# 2      178.75      Kitchenware            No                     0
# 3      220.35           Others             N                     0
# 4      220.35           Others            No                     0

# %%
df["STOCK_CODE"] = df["STOCK_CODE"].fillna("UNKNOWN")
df.head()
# Out:
#    CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 0      17850.0        NaN     85123A         2  2010-12-01 08:26:00
# 1      17850.0     536365      71053         8                  NaN
# 2     -17850.0        NaN     84406B         4  2010-12-01 08:26:00
# 3      17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4      17850.0     536365     84029E         1  2010-12-01 08:26:00
#
#    UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 0     -165.75           Others             N                     0
# 1      220.35           Others            NO                     0
# 2      178.75      Kitchenware            No                     0
# 3      220.35           Others             N                     0
# 4      220.35           Others            No                     0

# %%
df["UNIT_PRICE"].isnull().sum()
# Out:
# np.int64(31543)

# %%
df = df.dropna(subset = ["INVOICE_NO", "INVOICE_DATE"], inplace = True)

# %%
# df  = df.dropna("INVOICE_NO")
# df = df.dropna("INVOICE_DATE")

# %%
df["PRODUCT_CATEGORY"] = df["PRODUCT_CATEGORY"].fillna("Others")
df.head()
# Out:
#    CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 3      17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4      17850.0     536365     84029E         1  2010-12-01 08:26:00
# 5      17850.0     536365      22752         1  2010-12-01 08:26:00
# 7      17850.0     536366      22633         4  2010-12-01 08:28:00
# 8      17850.0     536366      22632         2  2010-12-01 08:28:00
#
#    UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 3      220.35           Others             N                     0
# 4      220.35           Others            No                     0
# 5     -497.25           Others            No                     0
# 7      120.25           Others            No                     0
# 8      120.25           Others             N                     0

# %%
df.isnull().sum()
# Out:
# CUSTOMER_ID             0
# INVOICE_NO              0
# STOCK_CODE              0
# QUANTITY                0
# INVOICE_DATE            0
# UNIT_PRICE              0
# PRODUCT_CATEGORY        0
# ITEM_RETURNED           0
# NO_OF_ITEMS_RETURNED    0
# dtype: int64

# %%
df[["CUSTOMER_ID","UNIT_PRICE","QUANTITY"]] = df[["CUSTOMER_ID","UNIT_PRICE","QUANTITY"]].abs()

# %%
df.head()
# Out:
#    CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 3      17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4      17850.0     536365     84029E         1  2010-12-01 08:26:00
# 5      17850.0     536365      22752         1  2010-12-01 08:26:00
# 7      17850.0     536366      22633         4  2010-12-01 08:28:00
# 8      17850.0     536366      22632         2  2010-12-01 08:28:00
#
#    UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 3      220.35           Others             N                     0
# 4      220.35           Others            No                     0
# 5      497.25           Others            No                     0
# 7      120.25           Others            No                     0
# 8      120.25           Others             N                     0

# %%
df["ITEM_RETURNED"].value_counts()
# Out:
# ITEM_RETURNED
# N      75684
# No     75551
# NO     74793
# YES     8433
# Y       8199
# Yes     8192
# Name: count, dtype: int64

# %%
df["ITEM_RETURNED"] = df["ITEM_RETURNED"].replace({"N" : "NO" , "No" : "NO" , "Y" : "YES" ,"Yes" : "YES"})

# %%
df["ITEM_RETURNED"].value_counts()
# Out:
# ITEM_RETURNED
# NO     226028
# YES     24824
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 3      17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4      17850.0     536365     84029E         1  2010-12-01 08:26:00
# 5      17850.0     536365      22752         1  2010-12-01 08:26:00
# 7      17850.0     536366      22633         4  2010-12-01 08:28:00
# 8      17850.0     536366      22632         2  2010-12-01 08:28:00
#
#    UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 3      220.35           Others            NO                     0
# 4      220.35           Others            NO                     0
# 5      497.25           Others            NO                     0
# 7      120.25           Others            NO                     0
# 8      120.25           Others            NO                     0

# %%
df[df["ITEM_RETURNED"]=="YES"].nunique()
# Out:
# CUSTOMER_ID              3211
# INVOICE_NO              10420
# STOCK_CODE               2796
# QUANTITY                   11
# INVOICE_DATE            10036
# UNIT_PRICE                214
# PRODUCT_CATEGORY            6
# ITEM_RETURNED               1
# NO_OF_ITEMS_RETURNED       15
# dtype: int64

# %%
df1 = df[df["NO_OF_ITEMS_RETURNED"] <= df["QUANTITY"]]

# %%
df1.head()
# Out:
#    CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 3      17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4      17850.0     536365     84029E         1  2010-12-01 08:26:00
# 5      17850.0     536365      22752         1  2010-12-01 08:26:00
# 7      17850.0     536366      22633         4  2010-12-01 08:28:00
# 8      17850.0     536366      22632         2  2010-12-01 08:28:00
#
#    UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 3      220.35           Others            NO                     0
# 4      220.35           Others            NO                     0
# 5      497.25           Others            NO                     0
# 7      120.25           Others            NO                     0
# 8      120.25           Others            NO                     0

# %%
df1.shape
# Out:
# (244495, 9)

# %%
df.shape
# Out:
# (250852, 9)

# %%
df2 = df1[~(
    (df1["ITEM_RETURNED"].str.upper().isin(["NO", "N"])) &
    (df1["NO_OF_ITEMS_RETURNED"] > 0)
)]

# %%
df2.shape
# Out:
# (238903, 9)

# %%
df2.head(100)
# Out:
#      CUSTOMER_ID INVOICE_NO STOCK_CODE  QUANTITY         INVOICE_DATE  \
# 3        17850.0     536365     84029G         2  2010-12-01 08:26:00
# 4        17850.0     536365     84029E         1  2010-12-01 08:26:00
# 5        17850.0     536365      22752         1  2010-12-01 08:26:00
# 7        17850.0     536366      22633         4  2010-12-01 08:28:00
# 8        17850.0     536366      22632         2  2010-12-01 08:28:00
# ..           ...        ...        ...       ...                  ...
# 156      16029.0     536386     85099C         2  2010-12-01 09:57:00
# 157      16029.0     536386     85099B         3  2010-12-01 09:57:00
# 160      16029.0     536387      22779         2  2010-12-01 09:58:00
# 161      16029.0     536387      22466         2  2010-12-01 09:58:00
# 162      16029.0     536387      21731         2  2010-12-01 09:58:00
#
#      UNIT_PRICE PRODUCT_CATEGORY ITEM_RETURNED  NO_OF_ITEMS_RETURNED
# 3        220.35           Others            NO                     0
# 4        220.35           Others            NO                     0
# 5        497.25           Others            NO                     0
# 7        120.25           Others            NO                     0
# 8        120.25           Others            NO                     0
# ..          ...              ...           ...                   ...
# 156      107.25           Others            NO                     0
# 157      107.25           Others            NO                     0
# 160      219.05           Others            NO                     0
# 161       94.25           Others            NO                     0
# 162       81.25           Others            NO                     0
#
# [100 rows x 9 columns]

# %%
# df2.to_excel("FINAL_PBL_DATA_SET_7.xlsx")

# %%
# df2.to_csv("FINAL_PBL_DATA_SET_7.csv", index = False)
